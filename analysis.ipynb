# %%
import pandas as pd
import plotly.express as px

# %%
pd.read_csv('results.csv')
# Out:
#                       timestamp  humidity  temperature
# 0    2023-04-22 05:55:03.962144      55.0        17.88
# 1    2023-04-22 11:55:04.076197      59.0        18.22
# 2    2023-04-22 18:20:03.913853      42.0        18.35
# 3    2023-04-23 07:50:04.166448      54.0        18.34
# 4    2023-04-23 08:20:04.718825      54.0        18.35
# ..                          ...       ...          ...
# 295  2023-04-23 05:20:04.088870      54.0        18.32
# 296  2023-04-22 22:00:04.179365      49.0        18.39
# 297  2023-04-22 11:00:04.517799      57.0        18.08
# 298  2023-04-23 00:35:03.973094      52.0        18.43
# 299  2023-04-23 09:30:04.129778      54.0        18.43
#
# [300 rows x 3 columns]

# %%
df = pd.read_csv('results_2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    567 non-null    object
#  1   humidity     567 non-null    float64
#  2   temperature  567 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 13.4+ KB

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df
# Out:
#                      timestamp  humidity  temperature
# 0   2023-04-22 05:55:03.962144      55.0        17.88
# 1   2023-04-22 11:55:04.076197      59.0        18.22
# 2   2023-04-22 18:20:03.913853      42.0        18.35
# 3   2023-04-23 07:50:04.166448      54.0        18.34
# 4   2023-04-23 08:20:04.718825      54.0        18.35
# ..                         ...       ...          ...
# 562 2023-04-21 22:35:04.663644      56.0        18.46
# 563 2023-04-22 04:05:04.546368      55.0        18.01
# 564 2023-04-22 11:45:03.896401      57.0        18.08
# 565 2023-04-23 04:50:04.439596      54.0        18.35
# 566 2023-04-22 19:15:04.428824      43.0        18.34
#
# [567 rows x 3 columns]

# %%
fig = px.scatter(df, x="timestamp", y="temperature", title='Temp in the grove!')
fig.show()

# %%
fig = px.scatter(df, x="timestamp", y="humidity", title='Temp in the grove!')
fig.show()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=2, cols=1)

fig.append_trace(go.scatter(x=df.timestamp, y=df.temperature,
    #x=[3, 4, 5],
    #y=[1000, 1100, 1200],
), row=1, col=1)

fig.append_trace(go.Scatter(
    x=[2, 3, 4],
    y=[100, 110, 120],
), row=2, col=1)


fig.update_layout(height=600, width=600, title_text="Stacked Subplots")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ben/Repos/raspi-weather-station/analysis.ipynb Cell 8 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> import plotly.graph_objects as go
#       <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> fig = make_subplots(rows=2, cols=1)
# ----> <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> fig.append_trace(go.scatter(x=df.timestamp, y=df.temperature,
#       <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     #x=[3, 4, 5],
#       <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     #y=[1000, 1100, 1200],
#       <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> ), row=1, col=1)
#      <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> fig.append_trace(go.Scatter(
#      <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>     x=[2, 3, 4],
#      <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     y=[100, 110, 120],
#      <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> ), row=2, col=1)
#      <a href='vscode-notebook-cell:/home/ben/Repos/raspi-weather-station/analysis.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a> fig.update_layout(height=600, width=600, title_text="Stacked Subplots")
#
# TypeError: 'module' object is not callable
